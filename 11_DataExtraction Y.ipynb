# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
# Read data from .csv file
X = np.genfromtxt('./data/X_wavelet_852.356.csv', delimiter=',')

# %%
print(f'shape of X: {X.shape}\nTotal number of sample is: {X.shape[0]}\nTotal number of features are: {X.shape[1]} ')
# Out:
# shape of X: (121, 4095)
# Total number of sample is: 121
# Total number of features are: 4095

# %%
i = 4
plt.plot(X[i,800:1200], alpha = 1)
plt.show()
print(np.argmax(X[i,800:1200]), np.argmin(X[i,800:1200]))
print(f'{(np.argmax(X[i,800:1200])+np.argmin(X[i,800:1200]))//2}, {(np.max(X[i, 800:1200])+np.min(X[i, 800:1200]))/2: .4f}')
# Out:
# <img src="data:image/png;base64,..." width="640">
# 323 169
# 246,  0.0511

# %%
for i in range(1,121):
    print(f'{(np.argmax(X[i,800:1200])+np.argmin(X[i,800:1200]))//2+800}, {(np.max(X[i, 800:1200])+np.min(X[i, 800:1200]))/2: .4f}')
# Out:
# 1074,  0.0603
# 1053,  0.0511
# 1062,  0.0655
# 1046,  0.0511
# 1046,  0.0671
# 1047,  0.0876
# 1046,  0.0578
# 1045,  0.0924
# 1043,  0.0920
# 1042,  0.0907
# 1030,  0.0766
# 1023,  0.0779
# 1023,  0.0898
# 1016,  0.0906
# 1015,  0.0913
# 1020,  0.0894
# 1018,  0.0913
# 1021,  0.0920
# 1020,  0.0925
# 1027,  0.0906
# 1019,  0.0912
# 1017,  0.0926
# 1022,  0.0916
# 1016,  0.0922
# 985,  0.0560
# 972,  0.0520
# 1001,  0.0953
# 1000,  0.0959
# 995,  0.0935
# 993,  0.0935
# 998,  0.0913
# 994,  0.0917
# 993,  0.0920
# 994,  0.0912
# 986,  0.0914
# 1000,  0.0885
# 994,  0.0872
# 1002,  0.0768
# 1008,  0.0767
# 1006,  0.0897
# 1013,  0.0754
# 1000,  0.0878
# 986,  0.0895
# 1012,  0.0691
# 997,  0.0781
# 1007,  0.0760
# 1002,  0.0744
# 968,  0.0619
# 1003,  0.0715
# 1004,  0.0688
# 961,  0.0618
# 955,  0.0621
# 993,  0.0675
# 952,  0.0610
# 949,  0.0626
# 948,  0.0612
# 947,  0.0627
# 951,  0.0605
# 949,  0.0618
# 953,  0.0619
# 953,  0.0624
# 956,  0.0618
# 952,  0.0611
# 950,  0.0627
# ...
