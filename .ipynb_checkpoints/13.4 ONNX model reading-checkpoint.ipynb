# %%
import onnx
import onnxruntime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
onnx_model_path = 'model2_singleoutput.onnx'
onnx_model = onnx.load(onnx_model_path)
onnx_runtime = onnxruntime.InferenceSession(onnx_model_path)

# %%
data = pd.read_csv('./data/merged_data_wavelet.csv')

# %%
len(data)
# Out:
# 120

# %%
sample = data.iloc[0]

# %%
np.reshape(sample.iloc[0:4095].values, (1, 1, 4095)).shape
# Out:
# (1, 1, 4095)

# %%
onnx_input = {onnx_runtime.get_inputs()[0].name: inputs.numpy()}
onnx_output = onnx_runtime.run(None, onnx_input)
onnx_output = torch.tensor(onnx_output[0])

# %%
for idx in range(0, len(data)):
    sample = data.iloc[idx]
    inputs = np.reshape(sample.iloc[0:4095].values, (1, 1, 4095))
    onnx_input = {onnx_runtime.get_inputs()[0].name: inputs.astype(np.float32)}
    onnx_output = onnx_runtime.run(None, onnx_input)
    actual_op = sample['y0']
    print(f'actual output {actual_op} \t predicted output{onnx_output[0][0][0]*4095}')
# Out:
# actual output 1066.0 	 predicted output1060.2864879369736
# actual output 1065.0 	 predicted output1056.966009736061
# actual output 1066.0 	 predicted output1055.2368177473545
# actual output 1041.0 	 predicted output1050.8029639720917
# actual output 1048.0 	 predicted output1048.6022074520588
# actual output 1048.0 	 predicted output1044.2207090556622
# actual output 1057.0 	 predicted output1046.2487782537937
# actual output 1048.0 	 predicted output1043.116364479065
# actual output 1057.0 	 predicted output1041.1225886642933
# actual output 1048.0 	 predicted output1038.487367928028
# actual output 1030.0 	 predicted output1030.5707220733166
# actual output 1021.0 	 predicted output1028.822979927063
# actual output 1030.0 	 predicted output1025.6084328889847
# actual output 1030.0 	 predicted output1023.7202221155167
# actual output 1023.0 	 predicted output1021.8422017246485
# actual output 1038.0 	 predicted output1026.218879520893
# actual output 1031.0 	 predicted output1026.2742859125137
# actual output 1038.0 	 predicted output1026.591225117445
# actual output 1035.0 	 predicted output1027.1334511041641
# actual output 1039.0 	 predicted output1030.0751155614853
# actual output 1032.0 	 predicted output1028.3256648480892
# actual output 1030.0 	 predicted output1028.1395530700684
# actual output 1039.0 	 predicted output1028.9915178716183
# actual output 1031.0 	 predicted output1026.4438001811504
# actual output 1005.0 	 predicted output1000.0382000952959
# actual output 981.0 	 predicted output985.0132437050343
# actual output 1019.0 	 predicted output1013.3026000857353
# actual output 1017.0 	 predicted output1012.6177087426186
# actual output 1015.0 	 predicted output1004.8794861137867
# actual output 1008.0 	 predicted output1004.7529911249876
# actual output 1007.0 	 predicted output1007.6925198733807
# actual output 1003.0 	 predicted output1005.5563838034868
# actual output 1008.0 	 predicted output1002.843728363514
# actual output 1003.0 	 predicted output1003.4342823922634
# actual output 987.0 	 predicted output997.672505825758
# actual output 1006.0 	 predicted output1001.2785588204861
# actual output 1002.0 	 predicted output999.7085076570511
# actual output 1010.0 	 predicted output1003.5355760157108
# actual output 1015.0 	 predicted output1013.3332322537899
# actual output 1021.0 	 predicted output1015.1172204315662
# actual output 1032.0 	 predicted output1011.2573231756687
# actual output 1017.0 	 predicted output1005.4171966016293
# actual output 991.0 	 predicted output995.2863697707653
# actual output 1009.0 	 predicted output997.0842705667019
# actual output 995.0 	 predicted output992.5786569714546
# actual output 1006.0 	 predicted output994.4405680149794
# actual output 982.0 	 predicted output986.6904464364052
# actual output 991.0 	 predicted output977.5048233568668
# actual output 986.0 	 predicted output983.096719533205
# actual output 976.0 	 predicted output974.3005277216434
# actual output 962.0 	 predicted output973.2071057707071
# actual output 986.0 	 predicted output971.6762296110392
# actual output 962.0 	 predicted output976.4628414809704
# actual output 962.0 	 predicted output966.7132692039013
# actual output 943.0 	 predicted output956.7157716304064
# actual output 942.0 	 predicted output950.2680663764477
# actual output 953.0 	 predicted output948.0627943575382
# actual output 950.0 	 predicted output951.0855547338724
# actual output 952.0 	 predicted output952.240973263979
# actual output 944.0 	 predicted output956.2542754411697
# actual output 955.0 	 predicted output959.5533965528011
# actual output 953.0 	 predicted output955.6862989068031
# actual output 943.0 	 predicted output949.4544222950935
# actual output 942.0 	 predicted output943.7759383767843
# actual output 962.0 	 predicted output949.9368484318256
# actual output 935.0 	 predicted output938.3817478269339
# actual output 944.0 	 predicted output940.2644057571888
# actual output 953.0 	 predicted output941.9484427571297
# actual output 940.0 	 predicted output943.4403269737959
# actual output 953.0 	 predicted output944.3804660439491
# actual output 953.0 	 predicted output940.5188602209091
# actual output 937.0 	 predicted output937.1063634753227
# actual output 944.0 	 predicted output938.3574617654085
# actual output 936.0 	 predicted output939.1185674071312
# actual output 957.0 	 predicted output941.0895826667547
# actual output 932.0 	 predicted output931.776549294591
# actual output 942.0 	 predicted output932.3927318304777
# actual output 920.0 	 predicted output931.2955266237259
# actual output 920.0 	 predicted output926.0239867866039
# actual output 940.0 	 predicted output934.8115137219429
# actual output 934.0 	 predicted output930.735604763031
# actual output 921.0 	 predicted output927.0640160143375
# actual output 937.0 	 predicted output919.3504455685616
# actual output 920.0 	 predicted output921.1607944965363
# actual output 929.0 	 predicted output924.0026908367872
# actual output 924.0 	 predicted output920.1164328306913
# actual output 925.0 	 predicted output918.7335918098688
# actual output 921.0 	 predicted output915.8996281027794
# actual output 915.0 	 predicted output911.6031309217215
# actual output 909.0 	 predicted output912.5634676963091
# actual output 917.0 	 predicted output916.7647732794285
# actual output 911.0 	 predicted output908.816579952836
# actual output 922.0 	 predicted output914.7850321233273
# actual output 907.0 	 predicted output909.7374366223812
# actual output 904.0 	 predicted output907.711686193943
# actual output 901.0 	 predicted output896.6698269546032
# actual output 897.0 	 predicted output903.1316278874874
# actual output 903.0 	 predicted output900.8992018550634
# actual output 898.0 	 predicted output897.970412671566
# actual output 892.0 	 predicted output894.7508009523153
# actual output 889.0 	 predicted output890.5516920983791
# actual output 897.0 	 predicted output889.2127856612206
# actual output 889.0 	 predicted output893.5760390013456
# actual output 883.0 	 predicted output895.4482624679804
# actual output 900.0 	 predicted output894.5449186116457
# actual output 890.0 	 predicted output882.5139820575714
# actual output 891.0 	 predicted output888.3938938379288
# actual output 876.0 	 predicted output881.5391834825277
# actual output 879.0 	 predicted output886.102522239089
# actual output 883.0 	 predicted output886.4085388183594
# actual output 876.0 	 predicted output859.6337051689625
# actual output 876.0 	 predicted output860.4439321160316
# actual output 877.0 	 predicted output887.2931494563818
# actual output 880.0 	 predicted output883.49555388093
# actual output 883.0 	 predicted output885.6337646394968
# actual output 887.0 	 predicted output883.2353024929762
# actual output 883.0 	 predicted output880.5607847124338
# actual output 875.0 	 predicted output877.494272813201
# actual output 869.0 	 predicted output872.7828989177942
# actual output 864.0 	 predicted output872.8142023086548

# %%
# Read data from .csv file
data = np.genfromtxt('./data/data_852.356_without_filter.csv', delimiter=',')

# %%
# We will seperate the data of each ramp slope

# get out the indices of minimum and maximum position in ramp value
min_index = np.where(data[:,0] == np.min(data[:,0]))
max_index = np.where(data[:,0] == np.max(data[:,0]))

print(f'min_index length: {np.shape(min_index)[1]}\nmax_index length: {np.shape(max_index)[1]} \n')
print(f'Min_indices: {min_index},\nMax_indices:{max_index}')
# Out:
# min_index length: 122
# max_index length: 121
#
# Min_indices: (array([  5019,  13209,  21399,  29589,  37779,  45969,  54159,  62349,
#         70539,  78729,  86919,  95109, 103299, 111489, 119679, 127869,
#        136059, 144249, 152439, 160629, 168819, 177009, 185199, 193389,
#        201579, 209769, 217959, 226149, 234339, 242529, 250719, 258909,
#        267099, 275289, 283479, 291669, 299859, 308049, 316239, 324429,
#        332619, 340809, 348999, 357189, 365379, 373569, 381759, 389949,
#        398139, 406329, 414519, 422709, 430899, 439089, 447279, 455469,
#        463659, 471849, 480039, 488229, 496419, 504609, 512799, 520989,
#        529179, 537369, 545559, 553749, 561939, 570129, 578319, 586509,
#        594699, 602889, 611079, 619269, 627459, 635649, 643839, 652029,
#        660219, 668409, 676599, 684789, 692979, 701169, 709359, 717549,
#        725739, 733929, 742119, 750309, 758499, 766689, 774879, 783069,
#        791259, 799449, 807639, 815829, 824019, 832209, 840399, 848589,
#        856779, 864969, 873159, 881349, 889539, 897729, 905919, 914109,
#        922299, 930489, 938679, 946869, 955059, 963249, 971439, 979629,
#        987819, 996009], dtype=int64),),
# Max_indices:(array([  9114,  17304,  25494,  33684,  41874,  50064,  58254,  66444,
#         74634,  82824,  91014,  99204, 107394, 115584, 123774, 131964,
#        140154, 148344, 156534, 164724, 172914, 181104, 189294, 197484,
#        205674, 213864, 222054, 230244, 238434, 246624, 254814, 263004,
#        271194, 279384, 287574, 295764, 303954, 312144, 320334, 328524,
#        336714, 344904, 353094, 361284, 369474, 377664, 385854, 394044,
#        402234, 410424, 418614, 426804, 434994, 443184, 451374, 459564,
#        467754, 475944, 484134, 492324, 500514, 508704, 516894, 525084,
#        533274, 541464, 549654, 557844, 566034, 574224, 582414, 590604,
#        598794, 606984, 615174, 623364, 631554, 639744, 647934, 656124,
#        664314, 672504, 680694, 688884, 697074, 705264, 713454, 721644,
#        729834, 738024, 746214, 754404, 762594, 770784, 778974, 787164,
#        795354, 803544, 811734, 819924, 828114, 836304, 844494, 852684,
#        860874, 869064, 877254, 885444, 893634, 901824, 910014, 918204,
#        926394, 934584, 942774, 950964, 959154, 967344, 975534, 983724,
#        991914], dtype=int64),)

# %%
pd1 = data[:, 1]
pd2 = data[:, 2]

pd1_0 = pd1[min_index[0][0]:max_index[0][0]]
pd2_0 = pd2[min_index[0][0]:max_index[0][0]]
pd_diff = pd1_0 - pd2_0

# %%
pd_diff
# Out:
# array([-11., -10., -14., ..., -60., -49., -47.])

# %%
# %matplotlib notebook
plt.plot(pd_diff)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import lockcoordinates
# Out:
# D:\Anaconda\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
output = lockcoordinates.LockCoordinates(onnx_model_path)

# %%
output.getLockingPoint(pd1_0, pd2_0)
# Out:
# (1059, 43)

# %%
0.25882423*4095
# Out:
# 1059.8852218499999
